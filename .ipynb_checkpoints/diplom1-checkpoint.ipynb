# %%
import numpy as np
import math 
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from sympy import *
# %matplotlib notebook
from numba import jit, njit

x1 = symbols('x1')
u1 = symbols('u1')

# %%
@njit
def thomasAlgorithm(A,d): #Tridiagonal matrix algorithm . Или метод прогонки
    n = len(d)
    P = np.zeros(n - 1)
    Q = np.zeros(n - 1)
    x = np.zeros(n)
    P[0] = A[0][1] / -A[0][0]
    Q[0] = -d[0] / -A[0][0]
    for i in range(1, n - 1): # находим прогоночные коэффициенты
        a = A[i][i-1]
        b = A[i][i]
        c = A[i][i+1]
        P[i] = c/(-b-a*P[i - 1])
        Q[i] =(a*Q[i - 1]-d[i])/(-b-a*P[i - 1])
    x[-1] = (A[n - 1][n - 2]*Q[n - 2] - d[n - 1]) / (-A[n - 1][n - 1] - A[n - 1][n - 2]*P[n - 2])
    for i in range(n-2, -1, -1): # Находим неизвекстные
        x[i] = P[i] * x[i + 1] + Q[i]
    return x

# %%
D = 20. #Хаотичное движение популяции
a = 2 # Рождаймость
K = 1.5 # количество ресурсов
sigma = 0.5# смертность

N = 10 #количество точек по оси OX
x0 = 0. # начало отрезка 
L = 100. # конец отрезка
h = (L - x0) / (N - 1) # шаг по OX

KT = 1000 #количество точек по времени
t0 = 0. # начальный момент времени
T = 100. # конечный момент времени
tau = (T - t0) / (KT - 1) # шаг по времени

s = tau*D/h**2 #sigma - число Куранта

A = np.zeros((N - 2, N - 2))
d = np.zeros((N - 2))

# %%
@njit
def solutionMatrixStart(): # заполнение матрицы решений краевыми условиями
    x = np.linspace(x0, L, N)
    u = np.zeros((N, KT))
    
    for i in range(0, KT): 
        u[0][i] = 0
        u[-1][i] = 0

    for i in range(0, N):
        u[i][0] = 0
        u[0][0] = 0
    return u, x

# %%
#@jit(nopython=True)
def createAndSolveMatrix(typeK): #заполняем трехдиагональную матрицу Ax=d
    u, x = solutionMatrixStart()

    for i in range(1,KT): 
        A[0, 0] = - 2*sigma - (a*tau*u[1][i - 1])/typeK(i, u[1][i-1]) - sigma*tau - 1
        A[0, 1] = sigma
        d[0] = (a*tau+1)*(-u[1][i - 1]) - sigma
        #print(sigma*u[0][i])

        for j in range(1, N-3):
            A[j, j - 1] = sigma
            A[j, j] = - 2*sigma - (a*tau*u[j + 1][i - 1])/typeK(i, u[j][i - 1]) - sigma*tau - 1
            A[j, j + 1] = sigma
            d[j] = (a*tau+1)*(-u[j + 1][i - 1])
    
        A[N - 3, N - 3] = - 2*sigma - (a*tau*u[N-2][i - 1])/typeK(i, u[N-2][i - 1]) - sigma*tau - 1
        A[N - 3, N - 4] = sigma
        d[N - 3] = (a*tau+1)*(-u[N-2][i - 1]) - sigma
        #print (A,d)
        u[1:N - 1, i] = thomasAlgorithm(A, d)
    return u, x

# %% [markdown]
# $$F(u)=au^k_j\cdot(1-u^{k+1}_j/K)- \sigma u^{k+1}_j$$

# %%
def typeK(i = 0, u1 = 0): return K

u, x = createAndSolveMatrix(typeK)

# %%
print("D = " + str(D) + ' a = ' + str(a) + " sigma = " + str(sigma) + " K0 = " + str(K) )
fig = plt.figure(facecolor='white')
ax = plt.axes(xlim=(-1, L), ylim=(0, 7) )
line, = ax.plot([ ], [ ], lw=3)
def redraw(i):
    line.set_data(x, u[:,i])
    string = 'Время:'+str(i)
    plt.suptitle(string)
anim = animation.FuncAnimation(fig,redraw,frames=KT,interval=500)
plt.grid(True)
plt.show()
# Out:
# D = 20.0 a = 2 sigma = 0.5 K0 = 1.5
# <img src="data:image/png;base64,..." width="640">

# %%
def Kt(t, u1=0): return 20/t

u, x = createAndSolveMatrix(Kt)

# %%
fig = plt.figure(facecolor='white')
ax = plt.axes(xlim=(-1, L), ylim=(0, 3) )
line, = ax.plot([ ], [ ], lw=3)
def redraw(i):
    line.set_data(x, u[:,i])
    string = 'Время:'+str(i)
    plt.suptitle(string)
anim = animation.FuncAnimation(fig,redraw,frames=KT,interval=500)
plt.grid(True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
K = 10
K1 = 1

def KTI(i, u1): return K + K1 * integrate(u1, (x1, x0, L))

u, x = createAndSolveMatrix(KTI)

# %%
print("D = " + str(D) + ' a = ' + str(a) + " sigma = " + str(sigma) + " K0 = " + str(K) + " K1 = " + str(K1))
fig = plt.figure(facecolor='white')
ax = plt.axes(xlim=(-1, L), ylim=(0, 1000) )
line, = ax.plot([ ], [ ], lw=3)
def redraw(i):
    line.set_data(x, u[:,i])
    string = 'Время:'+str(i)
    plt.suptitle(string)
anim = animation.FuncAnimation(fig,redraw,frames=KT,interval=500)
plt.grid(True)
plt.show()
# Out:
# D = 20.0 a = 2 sigma = 0.5 K0 = 10 K1 = 1

# %%
K = 10
K1 = 1

def KTInt(u1):
    return K + K1 * Integrate(u1)

def Integrate(u1):
    return integrate(u1, (x1, x0, L))


u, x = solutionMatrixStart()
for i in range(1,KT): #заполняем трехдиагональную матрицу Ax=d
    A[0, 0] = -2*s - sigma - 1
    A[0, 1] = sigma
    d[0] = -u[1][i - 1] - tau*a*u[1][i - 1]*(1 - Integrate(u[1][i - 1])/KTInt(u[1][i - 1]))  - sigma*u[0][i]  

    for j in range(1, N-3):
        A[j, j - 1] = sigma
        A[j, j] = -2*s - sigma - 1
        A[j, j + 1] = sigma
        d[j] = -u[j + 1][i - 1] - tau*a*u[j + 1][i - 1]*(1 - Integrate(u[j + 1][i - 1])/KTI(u[j + 1][i - 1]))
    
    A[N - 3, N - 3] = -2*s - sigma - 1
    A[N - 3, N - 4] = sigma
    d[N - 3] = -u[N-2][i - 1] - tau*a*u[N-2][i - 1]*(1 - Integrate(u[N-2][i - 1])/KTI(u[N-2][i - 1]))  - sigma*u[N-1][i]  
    #print (A,d)
    u[1:N - 1, i] = thomasAlgorithm(A, d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-bc3dd6d76fa0> in <module>()
#      19         A[j, j] = -2*s - sigma - 1
#      20         A[j, j + 1] = sigma
# ---> 21         d[j] = -u[j + 1][i - 1] - tau*a*u[j + 1][i - 1]*(1 - Integrate(u[j + 1][i - 1])/KTI(u[j + 1][i - 1]))
#      22
#      23     A[N - 3, N - 3] = -2*s - sigma - 1
#
# NameError: name 'KTI' is not defined

# %%
print("D = " + str(D) + ' a = ' + str(a) + " sigma = " + str(sigma) + " K0 = " + str(K) + " K1 = " + str(K1))
fig = plt.figure(facecolor='white')
ax = plt.axes(xlim=(-1, L), ylim=(0, 10) )
line, = ax.plot([ ], [ ], lw=3)
def redraw(i):
    line.set_data(x, u[:,i])
    string = 'Время:'+str(i)
    plt.suptitle(string)
anim = animation.FuncAnimation(fig,redraw,frames=KT,interval=100)
plt.grid(True)
plt.show()
# Out:
# D = 20.0 a = 9 sigma = 5 K0 = 10 K1 = 1
# <img src="data:image/png;base64,..." width="640">
